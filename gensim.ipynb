# %%
import gensim
import pprint

# %%
help(gensim)
# Out:
# Help on package gensim:
#
# NAME
#     gensim
#
# DESCRIPTION
#     This package contains interfaces and functionality to compute pair-wise document similarities within a corpus
#     of documents.
#
# PACKAGE CONTENTS
#     _matutils
#     corpora (package)
#     downloader
#     interfaces
#     matutils
#     models (package)
#     nosy
#     parsing (package)
#     scripts (package)
#     similarities (package)
#     sklearn_api (package)
#     summarization (package)
#     test (package)
#     topic_coherence (package)
#     utils
#     viz (package)
#
# DATA
#     logger = <Logger gensim (WARNING)>
#
# VERSION
#     3.8.3
#
# FILE
#     /Users/clare/miniconda3/lib/python3.7/site-packages/gensim/__init__.py

# %%
document = "Human machine interface for lab abc computer applications"

# %%
text_corpus = [
    "Human machine interface for lab abc computer applications",
    "A survey of user opinion of computer system response time",
    "The EPS user interface management system",
    "System and human system engineering testing of EPS",
    "Relation of user perceived response time to error measurement",
    "The generation of random binary unordered trees",
    "The intersection graph of paths in trees",
    "Graph minors IV Widths of trees and well quasi ordering",
    "Graph minors A survey",
]

# %%
# Create a set of frequent words
stoplist = {'for','and','a', 'of','the', 'to', 'in'}

# Lowercase each document, split it by white space and filter out stopwords
texts = [[word for document in text_corpus for word in document.lower().split()if word not in stoplist] for each_doc in text_corpus]

# %%
texts
# Out:
# [['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey']]

# %%
type(texts)
# Out:
# list

# %%
type(texts[0])
# Out:
# list

# %%
type(texts[0][1])
# Out:
# str

# %%
# Count word frequencies
from collections import defaultdict
frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

# %%
frequency
# Out:
# defaultdict(int,
#             {'human': 18,
#              'machine': 9,
#              'interface': 18,
#              'lab': 9,
#              'abc': 9,
#              'computer': 18,
#              'applications': 9,
#              'survey': 18,
#              'user': 27,
#              'opinion': 9,
#              'system': 36,
#              'response': 18,
#              'time': 18,
#              'eps': 18,
#              'management': 9,
#              'engineering': 9,
#              'testing': 9,
#              'relation': 9,
#              'perceived': 9,
#              'error': 9,
#              'measurement': 9,
#              'generation': 9,
#              'random': 9,
#              'binary': 9,
#              'unordered': 9,
#              'trees': 27,
#              'intersection': 9,
#              'graph': 27,
#              'paths': 9,
#              'minors': 18,
#              'iv': 9,
#              'widths': 9,
#              'well': 9,
#              'quasi': 9,
#              'ordering': 9})

# %%
# Only keep words that appear more than once
processed_corpus = [[token for token in text if frequency[token] > 1] for text in texts]
pprint.pprint(processed_corpus)
# Out:
# [['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey'],
#  ['human',
#   'machine',
#   'interface',
#   'lab',
#   'abc',
#   'computer',
#   'applications',
#   'survey',
#   'user',
#   'opinion',
#   'computer',
#   'system',
#   'response',
#   'time',
#   'eps',
#   'user',
#   'interface',
#   'management',
#   'system',
#   'system',
#   'human',
#   'system',
#   'engineering',
#   'testing',
#   'eps',
#   'relation',
#   'user',
#   'perceived',
#   'response',
#   'time',
#   'error',
#   'measurement',
#   'generation',
#   'random',
#   'binary',
#   'unordered',
#   'trees',
#   'intersection',
#   'graph',
#   'paths',
#   'trees',
#   'graph',
#   'minors',
#   'iv',
#   'widths',
#   'trees',
#   'well',
#   'quasi',
#   'ordering',
#   'graph',
#   'minors',
#   'survey']]
